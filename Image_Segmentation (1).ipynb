# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from random import randrange

# %%
image = cv2.imread("/content/drive/MyDrive/cv/image_segemtation/image_seg.jpeg")
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
_, binary_image = cv2.threshold(gray,100,255,cv2.THRESH_BINARY)

# %%
contours, _ = cv2.findContours(binary_image, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
segmented_image = image.copy()
cv2.drawContours(segmented_image, contours, -1,(0,0,255),2)
# Out:
# array([[[103,  49,  32],
#         [104,  50,  33],
#         [104,  51,  31],
#         ...,
#         [152,  85,   0],
#         [152,  85,   0],
#         [152,  85,   0]],
#
#        [[103,  49,  32],
#         [104,  50,  33],
#         [104,  51,  31],
#         ...,
#         [152,  85,   0],
#         [152,  85,   0],
#         [152,  85,   0]],
#
#        [[103,  49,  32],
#         [104,  50,  33],
#         [104,  51,  31],
#         ...,
#         [153,  86,   0],
#         [153,  86,   0],
#         [153,  86,   0]],
#
#        ...,
#
#        [[  0,   0, 255],
#         [  0,   0, 255],
#         [  0,   0, 255],
#         ...,
#         [ 50,  38,  26],
#         [ 50,  38,  28],
#         [ 48,  36,  24]],
#
#        [[  0,   0, 255],
#         [  0,   0, 255],
#         [  0,   0, 255],
#         ...,
#         [ 48,  36,  26],
#         [ 48,  35,  27],
#         [ 46,  34,  24]],
#
#        [[  0,   0, 255],
#         [  0,   0, 255],
#         [  0,   0, 255],
#         ...,
#         [ 58,  47,  39],
#         [ 58,  46,  40],
#         [ 56,  45,  37]]], dtype=uint8)

# %%
from google.colab.patches import cv2_imshow

# %%
cv2_imshow(segmented_image)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=206x245>
